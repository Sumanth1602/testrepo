# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **K Sayee Sumanth**
#
# Student

# %% [markdown]
# *I am interested in Data Science because I find it fascinating. I like finding stories behind what is hidden and find answers from unexpected places. Data although complex, noisy and challenging is more trustworthy source for answers, more so than people.*

# %% [markdown]
# #### The following code calculates simple division

# %%
72/6

# %% [markdown]
# This concludes the "Tools for Data Science" Module assignment.
#
# Here I have used the following:
# 1. Ordered List
# 2. [Hyperlink to Google](https://www.google.com)
# 3. ```python
#    s = "Code syntax highlighting"
#    print s
#    ```
